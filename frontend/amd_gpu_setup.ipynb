# %% [markdown]
# # NutriLife — AMD GPU Inference Setup
# This notebook documents running a self-hosted Gemma 2 model via vLLM on AMD MI300X GPU infrastructure (ROCm 7.2), used for AI meal plan generation in the NutriLife app.

# %%
# !vllm serve unsloth/gemma-2-9b-it --host 0.0.0.0 --port 8000
